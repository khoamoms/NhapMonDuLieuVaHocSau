# %%
import nltk
nltk.download('gutenberg')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('tagsets')
nltk.download('tagsets_json')
nltk.download('names')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# True

# %%
#câu 1
import nltk
import os

try:
    nltk_data_path = nltk.data.find('corpora')
    print("Danh sách các corpus đã được tải về máy/Colab:")
    print(os.listdir(nltk_data_path))
except LookupError:
    print("Chưa có corpus nào được tải về.")
# Out:
# Danh sách các corpus đã được tải về máy/Colab:
# ['wordnet.zip', 'gutenberg', 'stopwords.zip', 'names.zip', 'gutenberg.zip', 'names', 'stopwords']

# %%
#2
from nltk.corpus import stopwords

languages = stopwords.fileids()
print("Các ngôn ngữ hỗ trợ stopword trong NLTK:")
print(languages)
# Out:
# Các ngôn ngữ hỗ trợ stopword trong NLTK:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %%
#2
from nltk.corpus import stopwords

print("10 stopword tiếng Anh (English):", stopwords.words('english')[:10])
print("10 stopword tiếng Pháp (French):", stopwords.words('french')[:10])
print("10 stopword tiếng Tây Ban Nha (Spanish):", stopwords.words('spanish')[:10])
# Out:
# 10 stopword tiếng Anh (English): ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
# 10 stopword tiếng Pháp (French): ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle']
# 10 stopword tiếng Tây Ban Nha (Spanish): ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se']

# %%
#3
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

van_ban = "This is a very simple sentence showing how to filter out stopwords using NLTK."

tokens = word_tokenize(van_ban)
sw = set(stopwords.words('english'))

# Lọc bỏ từ dừng
van_ban_sach = [w for w in tokens if w.lower() not in sw]

print("Văn bản ban đầu:", tokens)
print("Văn bản sau khi lọc stopword:", van_ban_sach)
# Out:
# Văn bản ban đầu: ['This', 'is', 'a', 'very', 'simple', 'sentence', 'showing', 'how', 'to', 'filter', 'out', 'stopwords', 'using', 'NLTK', '.']
# Văn bản sau khi lọc stopword: ['simple', 'sentence', 'showing', 'filter', 'stopwords', 'using', 'NLTK', '.']

# %%
#4
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

van_ban = "This is a very simple sentence showing how to filter out stopwords using NLTK."

tokens = word_tokenize(van_ban)
sw = set(stopwords.words('english'))

# Lọc bỏ từ dừng
van_ban_sach = [w for w in tokens if w.lower() not in sw]

print("Văn bản ban đầu:", tokens)
print("Văn bản sau khi lọc stopword:", van_ban_sach)
# Out:
# Văn bản ban đầu: ['This', 'is', 'a', 'very', 'simple', 'sentence', 'showing', 'how', 'to', 'filter', 'out', 'stopwords', 'using', 'NLTK', '.']
# Văn bản sau khi lọc stopword: ['simple', 'sentence', 'showing', 'filter', 'stopwords', 'using', 'NLTK', '.']

# %%
#5
from nltk.corpus import stopwords

sw = set(stopwords.words('english'))
tu_muon_giu = {'not', 'no', 'but'}

# Loại bỏ các từ muốn giữ ra khỏi danh sách stopword mặc định
sw_tuy_bien = sw - tu_muon_giu

print(f"Số lượng từ dừng ban đầu: {len(sw)}")
print(f"Số lượng từ dừng sau khi loại bỏ: {len(sw_tuy_bien)}")
print("Từ 'not' có còn bị coi là stopword không?", 'not' in sw_tuy_bien)
# Out:
# Số lượng từ dừng ban đầu: 198
# Số lượng từ dừng sau khi loại bỏ: 195
# Từ 'not' có còn bị coi là stopword không? False

# %%
#6
from nltk.corpus import wordnet

tu_can_tim = "computer"
synsets = wordnet.synsets(tu_can_tim)

if synsets:
    dau_tien = synsets[0]
    print(f"Từ cần tra cứu: {tu_can_tim}")
    print(f"Định nghĩa (Definition): {dau_tien.definition()}")
    print(f"Ví dụ (Examples): {dau_tien.examples()}")
else:
    print("Không tìm thấy từ này trong cơ sở dữ liệu WordNet.")
# Out:
# Từ cần tra cứu: computer
# Định nghĩa (Definition): a machine for performing calculations automatically
# Ví dụ (Examples): []

# %%
#7
from nltk.corpus import wordnet

tu_nhap = "good"
dong_nghia = set()
trai_nghia = set()

for syn in wordnet.synsets(tu_nhap):
    for lemma in syn.lemmas():
        dong_nghia.add(lemma.name())
        if lemma.antonyms():
            for ant in lemma.antonyms():
                trai_nghia.add(ant.name())

print(f"Từ đồng nghĩa của '{tu_nhap}':", list(dong_nghia)[:10])
print(f"Từ trái nghĩa của '{tu_nhap}':", list(trai_nghia)[:10])
# Out:
# Từ đồng nghĩa của 'good': ['safe', 'commodity', 'effective', 'good', 'adept', 'near', 'right', 'trade_good', 'in_effect', 'dependable']
# Từ trái nghĩa của 'good': ['evilness', 'ill', 'badness', 'bad', 'evil']

# %%
#8
import nltk

print("--- Tổng quan về bộ tag Penn Treebank ---")
nltk.help.upenn_tagset()

print("\n--- Chi tiết về thẻ tag 'NN' (Danh từ số ít) ---")
nltk.help.upenn_tagset('NN')
# Out:
# --- Tổng quan về bộ tag Penn Treebank ---
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
#9
from nltk.corpus import wordnet

danh_tu_1 = wordnet.synset('dog.n.01')
danh_tu_2 = wordnet.synset('cat.n.01')

do_tuong_dong_n = danh_tu_1.path_similarity(danh_tu_2)
print(f"Độ tương đồng giữa danh từ 'dog' và 'cat' (từ 0 đến 1): {do_tuong_dong_n}")
# Out:
# Độ tương đồng giữa danh từ 'dog' và 'cat' (từ 0 đến 1): 0.2

# %%
#10
from nltk.corpus import wordnet

dong_tu_1 = wordnet.synset('run.v.01')
dong_tu_2 = wordnet.synset('walk.v.01')

do_tuong_dong_v = dong_tu_1.path_similarity(dong_tu_2)
print(f"Độ tương đồng giữa động từ 'run' và 'walk' (từ 0 đến 1): {do_tuong_dong_v}")
# Out:
# Độ tương đồng giữa động từ 'run' và 'walk' (từ 0 đến 1): 0.25

# %%
#11
from nltk.corpus import names

ten_nam = names.words('male.txt')
ten_nu = names.words('female.txt')

print(f"Tổng số lượng tên Nam (male.txt): {len(ten_nam)} tên")
print(f"Tổng số lượng tên Nữ (female.txt): {len(ten_nu)} tên")

print("\n10 tên Nam đầu tiên:", ten_nam[:10])
print("10 tên Nữ đầu tiên:", ten_nu[:10])
# Out:
# Tổng số lượng tên Nam (male.txt): 2943 tên
# Tổng số lượng tên Nữ (female.txt): 5001 tên
#
# 10 tên Nam đầu tiên: ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# 10 tên Nữ đầu tiên: ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']

# %%
#12
import random
from nltk.corpus import names

danh_sach_nhan = ([(name, 'male') for name in names.words('male.txt')] +
                  [(name, 'female') for name in names.words('female.txt')])

# Sử dụng seed cố định để không đổi kết quả khi bấm chạy lại
random.seed(42)
random.shuffle(danh_sach_nhan)

print("15 cặp kết hợp ngẫu nhiên đầu tiên (Tên, Nhãn giới tính):")
for item in danh_sach_nhan[:15]:
    print(item)
# Out:
# 15 cặp kết hợp ngẫu nhiên đầu tiên (Tên, Nhãn giới tính):
# ('Raye', 'female')
# ('Marita', 'female')
# ('Fey', 'female')
# ('Vittoria', 'female')
# ('Dannie', 'female')
# ('Annabela', 'female')
# ('Sayre', 'male')
# ('Brock', 'male')
# ('Angel', 'female')
# ('Bride', 'female')
# ('Ruthanne', 'female')
# ('Davina', 'female')
# ('Kingsley', 'male')
# ('Trixy', 'female')
# ('Shaine', 'female')

# %%
#13
from nltk.corpus import names

mang_ki_tu_cuoi = ([(name[-1].lower(), 'male') for name in names.words('male.txt')] +
                   [(name[-1].lower(), 'female') for name in names.words('female.txt')])

print(f"Tổng số lượng phần tử trong mảng mới: {len(mang_ki_tu_cuoi)}")
print("\n15 phần tử đầu tiên của mảng kí tự cuối (Kí tự cuối, Nhãn):")
for item in mang_ki_tu_cuoi[:15]:
    print(item)
# Out:
# Tổng số lượng phần tử trong mảng mới: 7944
#
# 15 phần tử đầu tiên của mảng kí tự cuối (Kí tự cuối, Nhãn):
# ('r', 'male')
# ('n', 'male')
# ('y', 'male')
# ('e', 'male')
# ('t', 'male')
# ('t', 'male')
# ('y', 'male')
# ('l', 'male')
# ('l', 'male')
# ('m', 'male')
# ('h', 'male')
# ('e', 'male')
# ('l', 'male')
# ('d', 'male')
# ('r', 'male')
